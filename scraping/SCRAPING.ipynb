# %%
pip install requests pandas lxml jupyterlab
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
from io import StringIO

url = "https://en.wikipedia.org/wiki/List_of_Academy_Award%E2%80%93winning_films"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
print(response.status_code)

tables = pd.read_html(StringIO(response.text))
print(f"Found {len(tables)} tables on the page")

df = tables[0]
df.head(10)
# Out:
# 200
# Found 2 tables on the page
#                        Film  Year Awards Nominations
# 0  One Battle After Another  2025      6          13
# 1                   Sinners  2025      4          16
# 2              Frankenstein  2025      3           9
# 3        KPop Demon Hunters  2025      2           2
# 4                    Hamnet  2025      1           8
# 5                   Weapons  2025      1           1
# 6         Sentimental Value  2025      1           9
# 7   Mr Nobody Against Putin  2025      1           1
# 8       All the Empty Rooms  2025      1           1
# 9               The Singers  2025      1           1

# %%
df = df.copy()

df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df = df.dropna(subset=['Year'])
df['Year'] = df['Year'].astype(int)

print(df.shape)
print(df['Year'].min(), "to", df['Year'].max())
# Out:
# (1336, 4)
# 1934 to 2025

# %%
import os
os.makedirs("../data", exist_ok=True)

df.to_csv("../data/movies_raw.csv", index=False)
print(f"Saved {len(df)} movies to movies_raw.csv")
# Out:
# Saved 1336 movies to movies_raw.csv
